# %%
import pandas as pd
import numpy as np

import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Saurabh Kotkar/Desktop/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df['pclass']=df['pclass'].astype(object)

# %%
df['pclass'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# survived         int64
# pclass          object
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
df=df.drop(['embarked'],axis=1)

# %%
df
# Out:
#      survived pclass     sex   age  sibsp  parch     fare   class    who
# 0           0      3    male  22.0      1      0   7.2500   Third    man  \
# 1           1      1  female  38.0      1      0  71.2833   First  woman
# 2           1      3  female  26.0      0      0   7.9250   Third  woman
# 3           1      1  female  35.0      1      0  53.1000   First  woman
# 4           0      3    male  35.0      0      0   8.0500   Third    man
# ..        ...    ...     ...   ...    ...    ...      ...     ...    ...
# 886         0      2    male  27.0      0      0  13.0000  Second    man
# 887         1      1  female  19.0      0      0  30.0000   First  woman
# 888         0      3  female   NaN      1      2  23.4500   Third  woman
# 889         1      1    male  26.0      0      0  30.0000   First    man
# 890         0      3    male  32.0      0      0   7.7500   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['deck']=df['deck'].fillna('C')

# %%
df['embark_town']=df['embark_town'].fillna('Southampton')

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# deck             0
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
df['age']=df['age'].fillna(df['age'].mean())

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
plt.boxplot(df['age'])
plt.xlabel('Age')
plt.ylabel('Distribution')
plt.title('Boxplot of Age')
plt.show()

# %%
import seaborn as sb

# Assuming 'sex' and 'survived' are categorical variables, and 'age' is numerical
sb.boxplot(x='sex', y='age', hue='survived', palette='Set2', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.histplot(x=df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.describe()
df
# Out:
#      survived pclass     sex        age  sibsp  parch     fare   class    who
# 0           0      3    male  22.000000      1      0   7.2500   Third    man  \
# 1           1      1  female  38.000000      1      0  71.2833   First  woman
# 2           1      3  female  26.000000      0      0   7.9250   Third  woman
# 3           1      1  female  35.000000      1      0  53.1000   First  woman
# 4           0      3    male  35.000000      0      0   8.0500   Third    man
# ..        ...    ...     ...        ...    ...    ...      ...     ...    ...
# 886         0      2    male  27.000000      0      0  13.0000  Second    man
# 887         1      1  female  19.000000      0      0  30.0000   First  woman
# 888         0      3  female  29.699118      1      2  23.4500   Third  woman
# 889         1      1    male  26.000000      0      0  30.0000   First    man
# 890         0      3    male  32.000000      0      0   7.7500   Third    man
#
# ...

# %%
sb.boxplot(x='class',y='sex', hue='survived',data=df)
# Out:
# <Axes: xlabel='class', ylabel='sex'>
